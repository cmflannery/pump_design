# %%
from centrifugalpump import Rocket, Pump
import matplotlib.pyplot as plt
import numpy as np

# %%
def main():
    plt.close('all')
    thrust = 4448.22  # Thrust in N (1000 lbf)
    Isp = 260  # reasonable value for Isp
    Of_ratio = 2.77

    rocket = Rocket(thrust, Isp, Of_ratio)
    rocket.culc()
    rocket.show()

    pump = Pump(rocket,"fuel")
    pump.culc_Ns()
    pump.design_size()
    pump.design_inlet()
    pump.design_outlet()
    pump.design_volute()
    pump.show()
    pump.plot_Non_dimensional_velocity_dia()
    pump.plot_slip_factor_dia()
    pump.plot_D2B2forNs_dia()
    plt.show()

# %%
main()
# Out:
# ==== Rocket Engine ====
# Thrust:		4448 (N)
# Isp:		260 (sec)
# O/F:		2.77
# Propellant Mass Flow:	1.74 (kg/s)
# Oxidizer Mass Flow:	1.28 (kg/s)
# Oxidizer Volumetric Flow Rate :	0.0011 (m3/s)
# Fuel Mass Flow:	0.46 (kg/s)
# Fuel Flow (Q):	0.0010 (m3/s)
# ==== Centrifugal Pump =====
# Action fluid density:	485 (kg/m3)
# Rotational Speed N:	16000 (rpm)
# Rotational Frequency N:	1675.5 (rad/s)
# Pump discharge pressure:	12.4 (MPa)
# Mass Flow Q:	2.40 (m3/min)
# Mass Flow q:	0.04 (m3/sec)
# Total Head H:	2607.73 (m)
# 比速度 *Something* Speed Ns:	67.9 (m min)
# Type Number K:	0.17
# ---- Impeller inlet design ----
# NPSH:		423.58 (m)
# tan(beta1):		0.304
# Inlet beta1:	16.92 (deg)
# suction sp. speed S:	1217.52
# Required NPSH Hsv:	2.70 (m)
# Coef of Hsv: 	0.21
# Inlet v1:		14.823 (m/s)
# Inlet w1:		50.920 (m/s)
# Shroud diameter Ds:	67.49 (mm)
# Hub Diameter Dh:	33.74 (mm)
# ---- Impeller outlet design ----
# sqrt(D2/B2):	6.02
# Theoretical than speed Ns_th:	67.92
# ...
